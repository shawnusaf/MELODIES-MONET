# %%
from melodies_monet import driver

an = driver.analysis()
an.control = 'control_boulderair_wrfchem.yaml'
an.read_control()
an.open_models()
an.read_analysis()
an.plotting()
an.stats()
# Out:
# wrfchem
# /glade/work/plichtig/melodies_monet/AQE/Tutorial/input_data/wrfout_hourly_d02_2022-07-1[1-7]*
# **** Reading WRF-Chem model output...
# Reading: ./output/boulderair/boulderair_wrfchem.nc4
# ...
# Reference std: 2.712591413488847
# ...
# Reference std: 0.16885729831681034
# ...
