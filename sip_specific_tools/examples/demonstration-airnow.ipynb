# %% [markdown]
# # Using MELODIES-MONET for SIP evaluation
#
# First, import the relevant library

# %%
from melodies_monet import driver

# %% [markdown]
# ## Reading the YAML file

# %%
an = driver.analysis()
an.control = "control_airnow_camx.yaml"
an.read_control()

# %% [markdown]
# ## Opening obs and models

# %%
an.open_models()
an.open_obs()
# Out:
# camx
# /glade/campaign/acom/acom-da/Denver2024-SIP/Denver_O3_2023/camx/outputs/runS20_2016/camxv72_cb6r5.201607*.runS20.avrg.grd03.nc
# /glade/u/home/plichtig/melodies-monet/monetio/monetio/models/_camx_mm.py:78: UserWarning: Filename for meteorological input not provided. Adding only altitude.
#   warnings.warn("Filename for meteorological input not provided. Adding only altitude.")
# /glade/work/plichtig/conda-envs/melodies-monet-test/lib/python3.11/site-packages/pyproj/crs/crs.py:1293: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)

# %% [markdown]
# ## Pair data and (if desired) save analysis

# %%
an.pair_data()
an.save_analysis()
# Out:
# 1, in pair data
# After pairing:                time  BARPR   BC   CO            NO           NO2  NO2Y  NOX  \
# 0       2016-05-06   -1.0 -1.0 -1.0 -1.000000e+00           NaN  -1.0 -1.0
# 1       2016-05-06   -1.0 -1.0 -1.0  9.634533e-08  3.000000e+00  -1.0 -1.0
# 2       2016-05-06   -1.0 -1.0 -1.0 -1.000000e+00           NaN  -1.0 -1.0
# 3       2016-05-06   -1.0 -1.0 -1.0  9.634533e-08  1.536682e-08  -1.0 -1.0
# 4       2016-05-06   -1.0 -1.0 -1.0  3.000000e+00           NaN  -1.0 -1.0
# ...            ...    ...  ...  ...           ...           ...   ...  ...
# 4990740 2016-08-20   -1.0 -1.0 -1.0 -1.000000e+00           NaN  -1.0 -1.0
# 4990741 2016-08-20   -1.0 -1.0 -1.0 -1.000000e+00           NaN  -1.0 -1.0
# 4990742 2016-08-20   -1.0 -1.0 -1.0 -1.000000e+00           NaN  -1.0 -1.0
# 4990743 2016-08-20   -1.0 -1.0 -1.0 -1.000000e+00           NaN  -1.0 -1.0
# 4990744 2016-08-20   -1.0 -1.0 -1.0 -1.000000e+00           NaN  -1.0 -1.0
#
# ...

# %% [markdown]
# ## Read analysis (if needed) and plot
#
# If the model has not been loaded, but you wish to plot spatial overlays, load

# %%
an.read_control()
an.plotting()
# Out:
# ...
# Reference std: 15.204158220876096
# ...
# Reference std: 8.877269737890954
# ...
# NOTE: Projection not defined for model 'camx'. Please add to surfplots.py. Setting to `ccrs.PlateCarree()`.
# ...
# NOTE: Projection not defined for model 'camx'. Please add to surfplots.py. Setting to `ccrs.PlateCarree()`.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
an.read_control()
an.stats()
