# %%
from melodies_monet import driver

an = driver.analysis()
an.control = 'control_pandora_wrfchem_no2.yaml'
an.read_control()
an.open_obs()
an.open_models()
an.pair_data()
an.plotting()
an.stats()
# Out:
# Importing pandora data. The data will be presented as hourly means.
# Calculating pandora hourly averages
# Calculating pandora hourly averages
# wrfchem
# /glade/work/plichtig/melodies_monet/AQE/Tutorial/input_data/wrfout_hourly_d02_2022-07-1[1-7]*
# **** Reading WRF-Chem model output...
# 1, in pair data
# After pairing:                       time     Column 2   Column 3   Column 4    Column 5  \
# 0     2018-06-01 16:00:00          NaN        NaN        NaN         NaN
# 1     2018-06-01 16:00:00  6726.681641  28.889999  37.730000  106.339996
# 2     2018-06-07 20:00:00          NaN        NaN        NaN         NaN
# 3     2018-06-07 20:00:00  6732.841797  29.029999  22.969999  226.554993
# 4     2018-06-26 18:00:00          NaN        NaN        NaN         NaN
# ...                   ...          ...        ...        ...         ...
# 28493 2025-02-10 23:00:00          NaN        NaN        NaN         NaN
# ...
